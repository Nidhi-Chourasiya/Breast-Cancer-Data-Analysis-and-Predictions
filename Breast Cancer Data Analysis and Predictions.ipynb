# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\Lenovo\\Downloads\\data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
def data(df1):
    return 'shape :',df1.shape, 'data types ; ', df1.dtypes, 'info :',df1.info(), 'unique value :',df1.nunique(), 'null_values :',df1.isnull().sum()

# %%
data(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df1=df.copy()

# %%
# drop irrelavent colunms

df.drop(['id','Unnamed: 32'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#The diagnosis of breast tissues (M = malignant, B = benign)

sns.countplot(df['diagnosis'])
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
df['diagnosis'].value_counts(1)*100
# Out:
# B    62.741652
# M    37.258348
# Name: diagnosis, dtype: float64

# %%
df.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
num=df.select_dtypes(include= np.number)
num.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
for i in num:
    sns.boxplot(num[i])
    plt.show()

# %%
for i in num:
    sns.histplot(num[i])
    plt.show()

# %%
for i in num:
    sns.barplot(y=num[i],x=df['diagnosis'])
    plt.show()

# %%
from scipy.stats import ttest_ind,shapiro,mannwhitneyu

# %%
dai_m=df[df['diagnosis']=='M']
dai_b=df[df['diagnosis']=='B']

# %%
for i in num:
    p_val=shapiro(num[i])
    print(p_val[1])
    if p_val[1]<0.05:
        print('signi')
    else:
        print('insigni')
# Out:
# 3.1061551985026026e-14
# signi
# 7.281473557441132e-08
# signi
# 7.01163031715385e-15
# signi
# 3.196511088521129e-22
# signi
# 8.59934589243494e-05
# signi
# 3.967941392408286e-17
# signi
# 1.3385831077542155e-21
# signi
# 1.4044357116065472e-19
# signi
# 7.88199550072477e-09
# signi
# 1.956494436320316e-16
# signi
# 1.2245553698549864e-28
# signi
# 3.5603670776690514e-19
# signi
# 7.587720866535223e-30
# signi
# 2.6527208249479415e-35
# signi
# 1.3619356940226007e-23
# signi
# 1.0828804875356465e-23
# signi
# 1.101693524093482e-31
# signi
# 7.82604378738137e-17
# signi
# 3.127301796951193e-24
# signi
# 8.551022688390013e-31
# signi
# 1.7043174747122154e-17
# signi
# 2.564881469879765e-06
# signi
# 1.3732817788019638e-17
# signi
# 5.59576708181488e-25
# signi
# 0.0002097362739732489
# signi
# 1.2475981315634304e-19
# signi
# 4.542876255013473e-17
# signi
# 1.9859026922919298e-10
# signi
# 3.234117707276973e-17
# signi
# 9.195529701560753e-20
# signi

# %%
signi=[]
insig=[]
for i in num:
    a=ttest_ind(dai_m[i],dai_b[i])
    print(a[1])
    if a[1]<0.05:
        signi.append(i)
    else:
        insig.append(i)
# Out:
# 8.465940572262422e-96
# 4.0586360478980736e-25
# 8.43625103617473e-101
# 4.734564310307344e-88
# 1.0518503592032013e-18
# 3.9382631058873895e-56
# 9.966555755072963e-84
# 7.101150161057422e-116
# 5.733384028466827e-16
# 0.7599368037256238
# 9.738948656461507e-50
# 0.8433320287670163
# 1.6519051758498057e-47
# 5.8955213926058635e-46
# 0.11029660865789295
# 9.975994654074587e-13
# 8.260176167970051e-10
# 3.0723087688180654e-24
# 0.8766418183858812
# 0.06307355082239346
# 8.482291921684414e-116
# 1.0780574879494241e-30
# 5.771397139668621e-119
# 2.828847704286693e-97
# 6.575143633984769e-26
# 7.069816352538377e-55
# 2.4646639567829224e-72
# 1.9690997072164375e-124
# 2.951120577154039e-25
# 2.316432449982829e-15

# %%
print(signi)
print('\n')
print(insig)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'radius_se', 'perimeter_se', 'area_se', 'compactness_se', 'concavity_se', 'concave points_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
#
#
# ['fractal_dimension_mean', 'texture_se', 'smoothness_se', 'symmetry_se', 'fractal_dimension_se']

# %%
df['diagnosis']=df['diagnosis'].map({'B':0,'M':1})

# %%
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']

# %%
x.shape
# Out:
# (569, 30)

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import PowerTransformer
sc=PowerTransformer()
x_sc=sc.fit_transform(x)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_sc,y, random_state=10,test_size=0.3)

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()

LR.fit(x_train,y_train)
from sklearn import model_selection
from sklearn import metrics

y_pred=LR.predict(x_test)
print(y_test.value_counts())

LR_acc=metrics.accuracy_score(y_test,y_pred)
print(LR_acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    112
# 1     59
# Name: diagnosis, dtype: int64
# 0.9824561403508771
# [[110   2]
#  [  1  58]]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(y_test.value_counts())

knn_acc=metrics.accuracy_score(y_test,y_pred)
print(knn_acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    112
# 1     59
# Name: diagnosis, dtype: int64
# 0.9824561403508771
# [[111   1]
#  [  2  57]]

# %%
GB=GaussianNB()
GB.fit(x_train,y_train)
y_pred=GB.predict(x_test)
print(y_test.value_counts())

GB_acc=metrics.accuracy_score(y_test,y_pred)
print(GB_acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    108
# 1     63
# Name: diagnosis, dtype: int64
# 0.9122807017543859
# [[99  9]
#  [ 6 57]]

# %%
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
y_pred=DT.predict(x_test)
print(y_test.value_counts())

DT_acc=metrics.accuracy_score(y_test,y_pred)
print(DT_acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    112
# 1     59
# Name: diagnosis, dtype: int64
# 0.9298245614035088
# [[105   7]
#  [  5  54]]

# %%
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
y_pred=RF.predict(x_test)
print(y_test.value_counts())

RF_acc=metrics.accuracy_score(y_test,y_pred)
print(RF_acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    112
# 1     59
# Name: diagnosis, dtype: int64
# 0.9824561403508771
# [[109   3]
#  [  0  59]]

# %%
RF.feature_importances_
# Out:
# array([0.06523806, 0.01756968, 0.09437952, 0.        , 0.00827904,
#        0.02785874, 0.03313008, 0.08671887, 0.00231613, 0.00684568,
#        0.02659097, 0.00505025, 0.01230875, 0.03594451, 0.00524479,
#        0.00463911, 0.00755427, 0.00713916, 0.00606065, 0.00577938,
#        0.12561552, 0.01558251, 0.14257885, 0.        , 0.01467903,
#        0.02360376, 0.06282138, 0.14313306, 0.00760731, 0.00573093])

# %%
# lets drop insing features

x_sig=df[signi]
y=df['diagnosis']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import PowerTransformer
sc=PowerTransformer()
x_sc=sc.fit_transform(x_sig)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_sc,y, random_state=0,test_size=0.3)

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()

LR.fit(x_train,y_train)
from sklearn import model_selection
from sklearn import metrics

y_pred=LR.predict(x_test)
print(y_test.value_counts())

acc=metrics.accuracy_score(y_test,y_pred)
print(acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    108
# 1     63
# Name: diagnosis, dtype: int64
# 0.9707602339181286
# [[106   2]
#  [  3  60]]

# %%
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
y_pred=RF.predict(x_test)
print(y_test.value_counts())

acc=metrics.accuracy_score(y_test,y_pred)
print(acc)

cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 0    108
# 1     63
# Name: diagnosis, dtype: int64
# 0.9590643274853801
# [[104   4]
#  [  3  60]]

# %%
acc1=['LR','KNN','GB','DT','RF']
acc=pd.DataFrame({'ACCURACY':[LR_acc,knn_acc,GB_acc,DT_acc,RF_acc]})
acc.index=['LR','KNN','GB','DT','RF']

# %%
acc
# Out:
#      ACCURACY
# LR   0.982456
# KNN  0.982456
# GB   0.912281
# DT   0.929825
# RF   0.982456

# %% [markdown]
# Logistic Regression model, KNN model,Random forest gave best performance with an accuracy of 98.24%
